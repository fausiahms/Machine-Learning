# %% [markdown]
# <a href="https://colab.research.google.com/github/fausiahms/Machine-Learning/blob/main/KUIS_2_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Husnul fausiah Ms.
#H081211021

# %%
#Import data dari drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Data
asuransi = pd.read_csv('/content/drive/MyDrive/SwedishMotorInsurance.csv')
asuransi
# Out:
#       Kilometres  Zone  Bonus  Make  Insured  Claims  Payment
# 0            1.0   1.0    1.0   1.0   455.13   108.0   392491
# 1            1.0   1.0    1.0   2.0    69.17    19.0    46221
# 2            1.0   1.0    1.0   3.0    72.88    13.0    15694
# 3            1.0   1.0    1.0   4.0  1292.39   124.0   422201
# 4            1.0   NaN    1.0   5.0   191.01    40.0   119373
# ...          ...   ...    ...   ...      ...     ...      ...
# 2177         5.0   7.0    7.0   5.0     8.74     0.0        0
# 2178         5.0   7.0    7.0   6.0    16.61     0.0        0
# 2179         5.0   7.0    7.0   7.0     2.83     1.0      966
# 2180         5.0   7.0    7.0   8.0    13.06     0.0        0
# 2181         5.0   7.0    7.0   9.0   384.87    16.0   112252
#
# [2182 rows x 7 columns]

# %%
asuransi.dtypes
# Out:
# Kilometres    float64
# Zone          float64
# Bonus         float64
# Make          float64
# Insured       float64
# Claims        float64
# Payment         int64
# dtype: object

# %% [markdown]
# Eksplorasi Data

# %%
asuransi.describe()
# Out:
#         Kilometres         Zone        Bonus         Make        Insured  \
# count  2181.000000  2181.000000  2181.000000  2181.000000    2182.000000
# mean      2.986703     3.971573     4.015131     4.990371    1092.195270
# std       1.410091     1.988296     2.000975     2.586734    5661.156245
# min       1.000000     1.000000     1.000000     1.000000       0.010000
# 25%       2.000000     2.000000     2.000000     3.000000      21.610000
# 50%       3.000000     4.000000     4.000000     5.000000      81.525000
# 75%       4.000000     6.000000     6.000000     7.000000     389.782500
# max       5.000000     7.000000     7.000000     9.000000  127687.270000
#
#             Claims       Payment
# count  2181.000000  2.182000e+03
# mean     51.888125  2.570076e+05
# std     201.754236  1.017283e+06
# min       0.000000  0.000000e+00
# 25%       1.000000  2.988750e+03
# 50%       5.000000  2.740350e+04
# 75%      21.000000  1.119538e+05
# max    3338.000000  1.824503e+07

# %%
casuransi = asuransi[['Kilometres', 'Zone','Bonus', 'Make','Insured','Claims']]
casuransi.head(10)
# Out:
#    Kilometres  Zone  Bonus  Make  Insured  Claims
# 0         1.0   1.0    1.0   1.0   455.13   108.0
# 1         1.0   1.0    1.0   2.0    69.17    19.0
# 2         1.0   1.0    1.0   3.0    72.88    13.0
# 3         1.0   1.0    1.0   4.0  1292.39   124.0
# 4         1.0   NaN    1.0   5.0   191.01    40.0
# 5         1.0   1.0    1.0   6.0   477.66    57.0
# 6         1.0   1.0    1.0   7.0   105.58    23.0
# 7         1.0   1.0    1.0   8.0    32.55    14.0
# 8         1.0   1.0    1.0   9.0  9998.46  1704.0
# 9         1.0   1.0    2.0   1.0   314.58    45.0

# %%
plt.scatter(casuransi.Insured, casuransi.Claims, color='red')
plt.xlabel("Insured")
plt.ylabel("Zone")
plt.show()

# %%
plt.scatter(casuransi.Insured, casuransi.Claims, color='red')
plt.xlabel("Insured")
plt.ylabel("Bonus")
plt.show()

# %%
# Impor library yang diperlukan
import pandas as pd
from sklearn.linear_model import LinearRegression

# Siapkan data dalam DataFrame
df = pd.DataFrame(asuransi)

# Pisahkan variabel independen dan dependen
x = df[['Payment']]
y = df[['Insured']]

# Inisialisasi model regresi linier
model = LinearRegression()

# Latih model pada data
model.fit(x, y)

# Dapatkan koefisien regresi dan intersep
koefisien = model.coef_
intersep = model.intercept_

# Cetak koefisien dan intersep
print("Koefisien Regresi:", koefisien)
print("Intersep:", intersep)
# Out:
# Koefisien Regresi: [[0.00519333]]
# Intersep: [-242.53097913]

# %%
import matplotlib.pyplot as plt
y_pred = model.predict(x)
plt.scatter(x, y, color='blue', label='Observasi')

# Plot garis regresi
plt.plot(x, y_pred, '-r')

# Label dan judul plot
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Regresi Linier Sederhana')

# Menampilkan legenda
plt.legend()

# Menampilkan plot
plt.show()
