# %% [markdown]
# <a href="https://colab.research.google.com/github/fausiahms/Machine-Learning/blob/main/Pert2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
#Import data dari drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataepl = pd.read_csv('/content/drive/MyDrive/epl-goalScorer(20-21).csv')

# %%
dataepl
# Out:
#      Unnamed: 0    id             player_name  games  time  goals         xG  \
# 0             0   647              Harry Kane     35  3097     23  22.174859
# 1             1  1250           Mohamed Salah     37  3085     22  20.250847
# 2             2  1228         Bruno Fernandes     37  3117     18  16.019454
# 3             3   453           Son Heung-Min     37  3139     17  11.023287
# 4             4   822         Patrick Bamford     38  3085     17  18.401863
# ..          ...   ...                     ...    ...   ...    ...        ...
# 517         517  9415  Jaden Philogene-Bidace      1     1      0   0.000000
# 518         518  9423         Gaetano Berardi      2   113      0   0.074761
# 519         519  9524          Anthony Elanga      1    67      0   0.000000
# 520         520  9540             Femi Seriki      1     1      0   0.000000
# 521         521  9552         Tyrese Francois      1    13      0   0.000000
#
# ...

# %%
#Melihat 5 data teratas
dataepl.head(5)
# Out:
#    Unnamed: 0    id      player_name  games  time  goals         xG  assists  \
# 0           0   647       Harry Kane     35  3097     23  22.174859       14
# 1           1  1250    Mohamed Salah     37  3085     22  20.250847        5
# 2           2  1228  Bruno Fernandes     37  3117     18  16.019454       12
# 3           3   453    Son Heung-Min     37  3139     17  11.023287       10
# 4           4   822  Patrick Bamford     38  3085     17  18.401863        7
#
#           xA  shots  key_passes  yellow_cards  red_cards position  \
# 0   7.577094    138          49             1          0        F
# 1   6.528526    126          55             0          0    F M S
# 2  11.474996    121          95             6          0      M S
# 3   9.512992     68          75             0          0    F M S
# 4   3.782247    107          30             3          0      F S
#
#           team_title  npg       npxG    xGChain  xGBuildup
# ...

# %%
#Melihat tipe data
dataepl.dtypes
#Int : Bilangan Bulat
#Float : Bilangan riil
#Object : Bukan bilangan
# Out:
# Unnamed: 0        int64
# id                int64
# player_name      object
# games             int64
# time              int64
# goals             int64
# xG              float64
# assists           int64
# xA              float64
# shots             int64
# key_passes        int64
# yellow_cards      int64
# red_cards         int64
# position         object
# team_title       object
# npg               int64
# npxG            float64
# xGChain         float64
# xGBuildup       float64
# dtype: object

# %%
#Menghapus kolom pertama hingga kedua
dataepl_no_id = dataepl.iloc[:,2:]
dataepl_no_id
# Out:
#                 player_name  games  time  goals         xG  assists  \
# 0                Harry Kane     35  3097     23  22.174859       14
# 1             Mohamed Salah     37  3085     22  20.250847        5
# 2           Bruno Fernandes     37  3117     18  16.019454       12
# 3             Son Heung-Min     37  3139     17  11.023287       10
# 4           Patrick Bamford     38  3085     17  18.401863        7
# ..                      ...    ...   ...    ...        ...      ...
# 517  Jaden Philogene-Bidace      1     1      0   0.000000        0
# 518         Gaetano Berardi      2   113      0   0.074761        0
# 519          Anthony Elanga      1    67      0   0.000000        0
# 520             Femi Seriki      1     1      0   0.000000        0
# 521         Tyrese Francois      1    13      0   0.000000        0
#
#             xA  shots  key_passes  yellow_cards  red_cards position  \
# 0     7.577094    138          49             1          0        F
# ...

# %%
#Another code
dataepl_no_player = dataepl.drop(dataepl.columns[2], axis=1)
dataepl_no_player
# Out:
#      Unnamed: 0    id  games  time  goals         xG  assists         xA  \
# 0             0   647     35  3097     23  22.174859       14   7.577094
# 1             1  1250     37  3085     22  20.250847        5   6.528526
# 2             2  1228     37  3117     18  16.019454       12  11.474996
# 3             3   453     37  3139     17  11.023287       10   9.512992
# 4             4   822     38  3085     17  18.401863        7   3.782247
# ..          ...   ...    ...   ...    ...        ...      ...        ...
# 517         517  9415      1     1      0   0.000000        0   0.000000
# 518         518  9423      2   113      0   0.074761        0   0.000000
# 519         519  9524      1    67      0   0.000000        0   0.000000
# 520         520  9540      1     1      0   0.000000        0   0.000000
# 521         521  9552      1    13      0   0.000000        0   0.000000
#
#      shots  key_passes  yellow_cards  red_cards position         team_title  \
# ...

# %%
#Statistika Deskriptif
dataepl.describe()
# Out:
#        Unnamed: 0           id       games         time       goals  \
# count  522.000000   522.000000  522.000000   522.000000  522.000000
# mean   260.500000  4380.932950   19.643678  1420.068966    1.862069
# std    150.832689  3281.776121   11.619836  1031.604819    3.338851
# min      0.000000    65.000000    1.000000     1.000000    0.000000
# 25%    130.250000   839.750000   10.000000   470.250000    0.000000
# 50%    260.500000  4627.000000   21.000000  1342.000000    1.000000
# 75%    390.750000  7690.500000   30.000000  2319.000000    2.000000
# max    521.000000  9552.000000   38.000000  3420.000000   23.000000
#
#                xG     assists          xA       shots  key_passes  \
# count  522.000000  522.000000  522.000000  522.000000  522.000000
# mean     2.000806    1.289272    1.376029   17.379310   12.963602
# std      3.317946    2.083350    1.886510   21.572664   16.164361
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %%
#Hubungan antarvariabel menggunakan korelasi
dataepl.loc[:,"games":].corr()
# Out:
# <ipython-input-17-0dd6518dfc79>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataepl.loc[:,"games":].corr()
#                  games      time     goals        xG   assists        xA  \
# games         1.000000  0.944591  0.439730  0.463869  0.504168  0.562806
# time          0.944591  1.000000  0.398930  0.411203  0.473555  0.516638
# goals         0.439730  0.398930  1.000000  0.932798  0.617490  0.607330
# xG            0.463869  0.411203  0.932798  1.000000  0.636205  0.627495
# assists       0.504168  0.473555  0.617490  0.636205  1.000000  0.885850
# xA            0.562806  0.516638  0.607330  0.627495  0.885850  1.000000
# shots         0.599164  0.529534  0.873363  0.910214  0.721220  0.759568
# key_passes    0.617867  0.575065  0.567752  0.570488  0.835299  0.946506
# ...

# %% [markdown]
# IMPOER DATA DENGAN API.KAGGLE

# %%
# !pip install kaggle #tanda seru menunjukkan route

# %%
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-85edc4af-dd19-43ea-a668-9c410d04b318" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85edc4af-dd19-43ea-a668-9c410d04b318">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "goal leagues"
